# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:\\Users\\srini\\OneDrive\\Desktop\\new_insurance_data.csv")

# %%
df
# Out:
#        age     sex     bmi  children smoker  Claim_Amount  past_consultations  \
# 0     18.0    male  23.210       0.0     no   29087.54313                17.0
# 1     18.0    male  30.140       0.0     no   39053.67437                 7.0
# 2     18.0    male  33.330       0.0     no   39023.62759                19.0
# 3     18.0    male  33.660       0.0     no   28185.39332                11.0
# 4     18.0    male  34.100       0.0     no   14697.85941                16.0
# ...    ...     ...     ...       ...    ...           ...                 ...
# 1333  33.0  female  35.530       0.0    yes   63142.25346                32.0
# 1334  31.0  female  38.095       1.0    yes   43419.95227                31.0
# 1335  52.0    male  34.485       3.0    yes   52458.92353                25.0
# 1336  45.0    male  30.360       0.0    yes   69927.51664                34.0
# 1337  54.0  female  47.410       0.0    yes   63982.80926                31.0
#
# ...

# %%
plt.boxplot(df['age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1d727fcef60>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1d727fdc440>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1d727aed340>],
#  'medians': [<matplotlib.lines.Line2D at 0x1d727fde270>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1d727fddf70>],
#  'means': []}

# %%
df['age'].isnull().sum()
# Out:
# 9

# %%
df['age'].dropna()
# Out:
# 0       18.0
# 1       18.0
# 2       18.0
# 3       18.0
# 4       18.0
#         ...
# 1333    33.0
# 1334    31.0
# 1335    52.0
# 1336    45.0
# 1337    54.0
# Name: age, Length: 1329, dtype: float64

# %%
df['age'].isnull().sum()
# Out:
# 9

# %%
plt.boxplot(df['age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1d72818a7b0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1d72818ad20>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1d72818a510>],
#  'medians': [<matplotlib.lines.Line2D at 0x1d72818b260>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1d72818b590>],
#  'means': []}

# %%
df.dropna(inplace=True)

# %%
plt.boxplot(df['age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1d7281fc590>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1d7281fcb90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1d7281fc320>],
#  'medians': [<matplotlib.lines.Line2D at 0x1d7281fd0d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1d7281fd370>],
#  'means': []}

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'Claim_Amount',
#        'past_consultations', 'num_of_steps', 'Hospital_expenditure',
#        'NUmber_of_past_hospitalizations', 'Anual_Salary', 'region', 'charges'],
#       dtype='object')

# %%
age_salary = df.groupby('age')['Anual_Salary'].mean().sort_index()
plt.figure(figsize=(16,10))
plt.plot(age_salary.index,age_salary.values,color='green')
plt.xlabel('Age')
plt.ylabel('Average Salary')
plt.title('Average Salary by Age')
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
#line plot'
age_children = df.groupby('age')['children'].mean().sort_index().round()
plt.figure(figsize=(16,10))
plt.plot(age_children.index,age_children.values,color='green')
plt.xlabel('Age')
plt.ylabel('Children')
plt.title('Children by Age')
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
#line plot
age_Hospital_expenditure = df.groupby('age')['Hospital_expenditure'].mean().sort_index()
plt.figure(figsize=(16,10))
plt.plot(age_Hospital_expenditure.index,age_Hospital_expenditure.values,color='green')
plt.xlabel('Age')
plt.ylabel('Hospital_expenditure')
plt.title('Hospital_expenditure by Age')
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
#scatter plot
plt.figure(figsize=(10,8))
plt.scatter(df['age'],df['bmi'],s=40,color='r',edgecolor='k',marker='*',label='scatter')
plt.xlabel('Age')
plt.ylabel('Bmi')
plt.title('Age Vs Bmi')
plt.legend()
plt.show()

# %%
#scatter plot
plt.figure(figsize=(15,9))
plt.scatter(df['age'],df['Claim_Amount'],s=100,marker='*',color='skyblue',edgecolor='k',label='Scatter')
plt.xlabel('Age')
plt.ylabel('Claim_Amount')
plt.title('Age Vs Claim Amount')
plt.legend()
plt.grid(axis='y')
plt.show()

# %%
#histogram
plt.figure(figsize=(10,5))
plt.hist(df['age'],color='gray',edgecolor='black',label='hist',alpha=0.6)
plt.xlabel('Age')
plt.legend()
plt.grid(linestyle=':',linewidth=1.5)
plt.show()

# %%
#hist
plt.figure(figsize=(2,1))
plt.hist(df['children'])
plt.show()

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'Claim_Amount',
#        'past_consultations', 'num_of_steps', 'Hospital_expenditure',
#        'NUmber_of_past_hospitalizations', 'Anual_Salary', 'region', 'charges'],
#       dtype='object')

# %%
#pie chart
region_counts=df['region'].value_counts()
#optional explode
explode=[0.1]*len(region_counts)
plt.figure(figsize=(6,6))
plt.pie(region_counts,labels=region_counts.index,explode=explode,autopct='%1.1f%%',shadow=True,startangle=360)
plt.title('Region distribution')
plt.axis('equal')
plt.show()

# %%
#pie chart
smoker_counts=df['smoker'].value_counts()
#optional explode
explode=[0.1]*len(smoker_counts)
plt.figure(figsize=(6,6))
plt.pie(smoker_counts,labels=smoker_counts.index,explode=explode,autopct='%1.1f%%',shadow=True,startangle=360)
plt.title('smoker distribution')
plt.axis('equal')
plt.show()

# %%
#bar
plt.figure(figsize=(10,6))
region=df['region'].value_counts()
plt.bar(region.index,region)
plt.xlabel('region')
plt.ylabel('count')
plt.title('region')
plt.show()

# %%
#bar
plt.figure(figsize=(10,6))
sex=df['sex'].value_counts()
plt.bar(sex.index,sex)
plt.xlabel('sex')
plt.ylabel('count')
plt.title('gender')
plt.show()

# %%
#box plot

plt.boxplot(df['age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1d7370e12b0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1d7370e2a80>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1d737628740>],
#  'medians': [<matplotlib.lines.Line2D at 0x1d7329f3080>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1d7376839e0>],
#  'means': []}

# %% [markdown]
# ### netflix dataset

# %%
#another dataset

df1=pd.read_csv("C:\\Users\\srini\\OneDrive\\Desktop\\NFLX.csv")

# %%
df1
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 1     2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2     2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 3     2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 4     2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
# ...          ...         ...         ...         ...         ...         ...
# 1004  2022-01-31  401.970001  427.700012  398.200012  427.140015  427.140015
# 1005  2022-02-01  432.959991  458.480011  425.540009  457.130005  457.130005
# 1006  2022-02-02  448.250000  451.980011  426.480011  429.480011  429.480011
# 1007  2022-02-03  421.440002  429.260010  404.279999  405.600006  405.600006
# 1008  2022-02-04  407.309998  412.769989  396.640015  410.170013  410.170013
#
#         Volume
# 0     11896100
# ...

# %% [markdown]
# ### lineplot

# %%
df1['Date']=pd.to_datetime(df1['Date'])
#line plot
plt.figure(figsize=(20,8))
plt.plot(df1['Date'],df1['Adj Close'],color='r')
plt.show()

# %%
#get 10 evenly spaced dates from the dataset
tick_dates=df1['Date'].iloc[::len(df1)//10][:10]
plt.figure(figsize=(20,8))
plt.plot(df1['Date'],df1['Adj Close'],color='r')
plt.xlabel('Date')
plt.ylabel('Adjusted Close Price')
plt.title('Adjusted Close Price over time')

#use only 10 ticks
plt.xticks(tick_dates,rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Scatter plot

# %%
#scatter plot
plt.figure(figsize=(10,6))
plt.scatter(df1['Open'],df1['Close'],color='red',edgecolor='black',marker='o',s=50,label='Scatter')
plt.xlabel('Open')
plt.ylabel('Close')
plt.title('Open & Close')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Histogram

# %%
#histogram
plt.figure(figsize=(10,8))
plt.hist(df1['Open'],bins=30,alpha=0.5,color='gray',edgecolor='k')
plt.xlabel('Open')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### chocolate dataset

# %%
df2=pd.read_csv("C:\\Users\\srini\\OneDrive\\Desktop\\Chocolate Sales.csv")

# %%
df2
# Out:
#           Sales Person    Country              Product       Date    Amount  \
# 0       Jehu Rudeforth         UK      Mint Chip Choco  04-Jan-22   $5,320
# 1          Van Tuxwell      India        85% Dark Bars  01-Aug-22   $7,896
# 2         Gigi Bohling      India  Peanut Butter Cubes  07-Jul-22   $4,501
# 3         Jan Morforth  Australia  Peanut Butter Cubes  27-Apr-22  $12,726
# 4       Jehu Rudeforth         UK  Peanut Butter Cubes  24-Feb-22  $13,685
# ...                ...        ...                  ...        ...       ...
# 1089  Karlen McCaffrey  Australia  Spicy Special Slims  17-May-22   $4,410
# 1090    Jehu Rudeforth        USA           White Choc  07-Jun-22   $6,559
# 1091      Ches Bonnell     Canada  Organic Choco Syrup  26-Jul-22     $574
# 1092    Dotty Strutley      India              Eclairs  28-Jul-22   $2,086
# 1093  Karlen McCaffrey      India       70% Dark Bites  23-May-22   $5,075
#
#       Boxes Shipped
# 0               180
# 1                94
# ...

# %% [markdown]
# ### hist plot

# %%
plt.figure(figsize=(10,10))
plt.hist(df2['Boxes Shipped'],bins=30,alpha=0.5,color='gray',edgecolor='k',label='Boxes')
plt.xlabel('Boxes Shipped')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %% [markdown]
# ### pie chart

# %%
#pie chart
Country_counts=df2['Country'].value_counts()
#optional explode
explode=[0.1]*len(Country_counts)
plt.figure(figsize=(6,6))
plt.pie(Country_counts,labels=Country_counts.index,explode=explode,autopct='%1.1f%%',shadow=True,startangle=360)
plt.title('Country distribution')
plt.axis('equal')
plt.show()

# %% [markdown]
# ### bar plot

# %%
plt.figure(figsize=(10,6))
#create bar chart
plt.bar(df2['Product'],df2['Boxes Shipped'],color='red',edgecolor='k',label='Boxes',alpha=0.5)
plt.grid(True,linestyle=':',linewidth=0.05)
#labels
plt.xlabel('Product')
plt.ylabel('Boxes Shipped')
plt.title('Products and Boxes Shipped')
plt.legend()
plt.show()

# %% [markdown]
# ### box plot

# %%
plt.boxplot(df2['Boxes Shipped'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1d73a1db200>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1d73a1db3e0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1d73a1daab0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1d73a1dbb60>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1d73a1d8830>],
#  'means': []}

# %% [markdown]
# ### Mobile sales dataset

# %%
df3=pd.read_csv("C:\\Users\\srini\\OneDrive\\Desktop\\mobile_sales_data.csv")

# %%
df3
# Out:
#             Product      Brand Product Code  \
# 0      Mobile Phone   Motorola     88EB4558
# 1            Laptop       Oppo     416DFEEB
# 2      Mobile Phone    Samsung     9F975B08
# 3            Laptop       Sony     73D2A7CC
# 4            Laptop  Microsoft     CCE0B80D
# ...             ...        ...          ...
# 49995        Laptop   Motorola     8C187637
# 49996        Laptop         HP     0DA9E4D3
# 49997        Laptop    Toshiba     CAD89A93
# 49998  Mobile Phone     Lenovo     78566C17
# 49999        Laptop       Asus     9C3FC57C
#
#                                    Product Specification   Price Inward Date  \
# 0      Site candidate activity company there bit insi...   78570  2023-08-02
# 1                Beat put care fight affect address his.   44613  2023-10-03
# 2               Energy special low seven place audience.  159826  2025-03-19
# 3      Friend record hard contain minute we role sea ...   20911  2024-02-06
# ...

# %% [markdown]
# ### students habits

# %%
df4=pd.read_csv("C:\\Users\\srini\\OneDrive\\Desktop\\student_habits_performance.csv")

# %%
df4
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 2        S1002   21    Male                  1.4                 3.1
# 3        S1003   23  Female                  1.0                 3.9
# 4        S1004   19  Female                  5.0                 4.4
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...
